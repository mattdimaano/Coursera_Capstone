# %%
import pandas as pd

df1 = pd.read_csv(r"C:\Users\MatthewDimaano\Documents\projects\Coursera_Capstone\Toronto_df_clean.csv")
df2 = pd.read_csv(r"C:\Users\MatthewDimaano\Documents\projects\Coursera_Capstone\Geospatial_Coordinates.csv")

# %%
df_final=df1.merge(df2, left_on='Postcode', right_on='Postal Code')

# %%
df_final=df_final.drop('Postal Code', 1)

# %%
df_final
# Out:
#    Postcode           Borough  \
# 0       M1B       Scarborough
# 1       M1J       Scarborough
# 2       M1R       Scarborough
# 3       M2H        North York
# 4       M4B         East York
# 5       M4G         East York
# 6       M4M      East Toronto
# 7       M5A  Downtown Toronto
# 8       M5G  Downtown Toronto
# 9       M5V  Downtown Toronto
# 10      M9L        North York
# 11      M9V         Etobicoke
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                       Rouge,Malvern  43.806686 -79.194353
# 1                                 Scarborough Village  43.744734 -79.239476
# 2                                    Maryvale,Wexford  43.750072 -79.295849
# 3                                   Hillcrest Village  43.803762 -79.363452
# 4                      Parkview Hill,Woodbine Gardens  43.706397 -79.309937
# 5                                             Leaside  43.709060 -79.363452
# ...
